# %% [markdown]
# # Reading a file

# %%
import os

# %%
file=open("Python.txt",'w')
file.close()

# %%
file=open("Python.txt",'r')
print(file.read())
file.close()
# Out:
# New Lines to The FileNow the file has more content!

# %%
#readinf the file in other location
f = open("F:\RABIN\Tutorials\Edurika python 12 hours course\Pyhton 12 hours course edurika.txt", "r")
print(f.readlines(5))
# Out:
# ['** Python Programming Certification Course: https://www.edureka.co/python-program... **\n']

# %%
#looping over a file to read
f = open("F:\RABIN\Tutorials\Edurika python 12 hours course\Pyhton 12 hours course edurika.txt", "r")
for line in f:
    print(f.readlines(5))
# Out:
# ['This Edureka Python Tutorial for Beginners will help you learn Python programming language and its core concepts with examples from scratch. This Python tutorial video helps you to learn the following concepts:\n']
# ['1:55 What is Python?\n']
# ['4:55 Features of Python\n']
# ['7:50 Learning Path\n']
# ['10:30 How Netflix use Python?\n']
# ['18:15 Python Developer Salary\n']
# ['19:20 Python Developer Job Trends\n']
# ['23:05 Who is a Python developer?\n']
# ['41:40 Emerging Job Roles\n']
# ['47:05 Python Installation\n']
# ['58:35 Best IDE for Python\n']
# ['59:50 Features of an IDE\n']
# ['1:07:40 PyCharm Tutorial\n']
# ['1:09:07 Features of PyCharm\n']
# ['1:28:52 What are Comments?\n']
# ['1:30:22 How to write comments in Python?\n']
# ['1:35:57 Docstring Comments\n']
# ['1:39:17 Variable definition & Declaration\n']
# ['1:41:42 Numbers\n']
# ['1:46:02 List\n']
# ['1:50:12 Tuple\n']
# ['1:53:52 Type Conversion\n']
# ['1:57:12 Specialised Collections Data Types\n']
# ...

# %%
#looping over a file
f = open("F:\RABIN\Tutorials\Edurika python 12 hours course\Pyhton 12 hours course edurika.txt", "r")
for x in f:
  print(x)
# Out:
# ** Python Programming Certification Course: https://www.edureka.co/python-program... **
#
# This Edureka Python Tutorial for Beginners will help you learn Python programming language and its core concepts with examples from scratch. This Python tutorial video helps you to learn the following concepts:
#
#
#
# 1:55 What is Python?
#
# 3:40 Why is Python popular?
#
# 4:55 Features of Python
#
# 6:50 Where is Python used in the industry?
#
# 7:50 Learning Path
#
# 9:15 Career Opportunities
#
# 10:30 How Netflix use Python?
#
# 11:55 How does it use Python?
#
# 18:15 Python Developer Salary
#
# 18:50 Who is Python Developer?
#
# 19:20 Python Developer Job Trends
#
# 21:55 How to become a Python Developer?
#
# 23:05 Who is a Python developer?
#
# 33:50 Job Roles
#
# 41:40 Emerging Job Roles
#
# 44:30 Road Map
#
# 47:05 Python Installation
#
# 54:30 How to run a Python program?
#
# 58:35 Best IDE for Python
#
# 59:35 What is an IDE?
#
# 59:50 Features of an IDE
#
# ...

# %%
f = open("demofile2.txt", "a")
f.write("Now the file has more content!")
f.close()

#open and read the file after the appending:
f = open("demofile2.txt", "r")
print(f.read())
# Out:
# Now the file has more content!

# %%
os.remove("demo.txt")
